# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 42.7 MB 52 kB/s  eta 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_parquet("https://samplefile.com/samples/download/data/parquet/parquet_alltypes_plain_sample.parquet/")

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
# !pip install pyarrow

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
df = pd.read_parquet("https://samplefile.com/samples/download/data/parquet/parquet_alltypes_plain_sample.parquet/")

# %%
df.head()
# Out:
#    id  bool_col  tinyint_col  smallint_col  int_col  bigint_col  float_col  \
# 0   4      True            0             0        0           0        0.0
# 1   5     False            1             1        1          10        1.1
# 2   6      True            0             0        0           0        0.0
# 3   7     False            1             1        1          10        1.1
# 4   2      True            0             0        0           0        0.0
#
#    double_col date_string_col string_col       timestamp_col
# 0         0.0     b'03/01/09'       b'0' 2009-03-01 00:00:00
# 1        10.1     b'03/01/09'       b'1' 2009-03-01 00:01:00
# 2         0.0     b'04/01/09'       b'0' 2009-04-01 00:00:00
# 3        10.1     b'04/01/09'       b'1' 2009-04-01 00:01:00
# 4         0.0     b'02/01/09'       b'0' 2009-02-01 00:00:00

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.0.2'
